# %% [markdown]
# <img src="https://filoger.com/wp-content/uploads/2021/09/circle-logo-1536x1536.png" alt="keras" width="150" height="150">
# <h1 align=center><font size = 7>Lab 01 : Python</font></h1>
# <h1 align=center><font size = 4>Filoger Summer School, 1401 | DeadLine: 15th Tir, 23:00 </font></h1>

# %% [markdown]
# ## Question Sheet!
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size = 3>
#
# <b>Download the Question sheet from the following link!</b>
# -   <a href="https://new.edmodo.com/groups/filoger-summer-school-38664125">Lab 01: Question sheet: Python</a>
# </font>
# </div>

# %% [markdown]
# ## Table of Exercises!
#
# 01. [Question 01](#question01)
# 2. [Question 02](#question02).
# 3. [Question 03](#question03).
# 4. [Question 04](#question04).
# 5. [Question 05](#question05).
# 6. [Question 06](#question06).

# %% [markdown]
# <a id='item312'></a>

# %% [markdown]
# <a id='question01'></a>
# ## Question 01

# %%
#Leave the answer of question 01 here!
S='Hi. Welcome to Filoger AI Bootcamp.'
S.split()
# Out:
# ['Hi.', 'Welcome', 'to', 'Filoger', 'AI', 'Bootcamp.']

# %% [markdown]
# <a id='question02'></a>
# ## Question 02

# %%
#Leave the answer of question 02 here!
n  = len(S.split())
print("This sentence has {} words.".format(n))
# Out:
# This sentence has 6 words.

# %% [markdown]
# <a id='question03'></a>
# ## Question 03

# %%
#Leave the answer of question 03 here!
n  = len(S.split('.'))
print("This sentence has {} sentenses.".format(n))
# Out:
# This sentence has 2 sentenses.

# %% [markdown]
# <a id='question04'></a>
# ## Question 04

# %%
#Leave the answer of question 04 here!
def split_email(email):
    domain = email.split('@')[1]
    return  domain
split_email('user@domain.com')
# Out:
# 'domain.com'

# %% [markdown]
# <a id='question05'></a>
# ## Question 05

# %%
#Leave the answer of question 05 here!
def has_word(word, sentence):
    if word in sentence:
        return True
    else:
        return False
has_word('Iran', "Sir, I am in Iran.")
# Out:
# True

# %% [markdown]
# <a id='question06'></a>
# ## Question 06

# %%
#Leave the answer of question 06 here!
def ticket_price(speed,birthDate,accidentDate):
    if(birthDate == accidentDate):
        if speed <=65:
            return "No Ticket"
        elif 65<speed<=85:
            return "Small Ticket"
        elif speed >85:
            return "Big Ticket"
    else:        
        if speed <= 60:
            return "No Ticket"
        elif 60<speed<=80:
            return  "Small Ticke"
        elif speed > 80:
            return "Big Ticket"




print(ticket_price(65, '01/01/2000', '01/01/2000'))
print(ticket_price(65, '01/22/2000', '01/01/2000'))
# Out:
# No Ticket
# Small Ticke

# %% [markdown]
# ## Best Wishes!, Filoger
